# %% [markdown]
# # TD5 – CAH (Classification Ascendante Hiérarchique)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Exercice 1 : Insuffisance rénale

# %% [markdown]
# ### 1. Chargement du dataset

# %% [markdown]
# ### 2. Taille et valeurs manquantes

# %% [markdown]
# ### 3. Valeurs maximales par colonne

# %% [markdown]
# ### 4. Données sans la feature cible

# %% [markdown]
# ### 5. Dendogramme (linkage)

# %% [markdown]
# ### 6. AgglomerativeClustering – 3 clusters

# %% [markdown]
# ### 7. Colonnes `cluster` et `class`

# %% [markdown]
# ### 8. Insuffisance rénale par cluster

# %% [markdown]
# ## Exercice 2 : Données normalisées

# %% [markdown]
# ### 1. Normalisation StandardScaler

# %% [markdown]
# ### 2. Répartition des données

# %% [markdown]
# ### 3. Nouveau dendogramme

# %% [markdown]
# ### 4. Clusterisation 3 clusters (normalisé)

# %% [markdown]
# ### 5. Répartition classes / clusters
